# %%
## Import the required libraries
import urllib2
from pymarc import Field, Record
from BeautifulSoup import BeautifulSoup
import cgi
# setup a variable for excaping HTML chars
html_escape_table = {
                     "&": "&amp;",
                     '"': "&quot;",
                     "'": "&apos;",
                     ">": "&gt;",
                     "<": "&lt;",
                     }
## define a function that will escape strings of text for use in xml
def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text) 

## read the A-Z list and create  a list of guides to parse
page = urllib2.urlopen('http://lawlibraryguides.bu.edu/browse.php')
rpage = page.read()
soup =  BeautifulSoup(rpage)
a_list = soup.fetch('a', {'class' : 'pdisplay_name'})
href_list = []
for href in a_list:
    href_list.append('http://lawlibraryguides.bu.edu' + href['href'])


## open the xml file and write the header
f = open('LawGuides.xml', 'wb')
f.write('<?xml version="1.0" encoding="UTF-8"?>\n')
f.write('<OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">\n')
f.write('<responseDate>2014-07-17T21:02:57Z</responseDate>\n')
f.write('    <request verb="ListRecords" metadataPrefix="oai_dc" >http://lawlibraryguides.bu.edu/</request>\n')
f.write('<ListRecords>\n')

## write each record
i = 0

while i < len(href_list):
    page = urllib2.urlopen(href_list[i])
    rpage = page.read()
    parsed_html =  BeautifulSoup(rpage)
    metaList = parsed_html.fetch('meta')
    x = 11

    while x < 22:
        if x == 11:
            title = metaList[11]['content']
            title = title[:-1]
            title = title[:title.rfind('.')]
            title = title[11:]
            title += ' (Research Guide)'
        elif x == 12:
            creator = metaList[12]['content']
        elif x == 13:
            subject = metaList[13]['content']
            if subject[0:4] == 'Home':
                subject = subject[5:]
            if subject[-9:] == 'LibGuides':
                subject = subject[0:-9]
        elif x == 14:
            description = metaList[14]['content']
            #description = description[:-1]
            if description[0:9] == 'LibGuides':
                description = description[11:]
            if description.rfind('Home.') > 0:
                description = description[:description.rfind('Home.')]
            #print description
        elif x == 15:
            publisher =  metaList[15]['content']
            if publisher.rfind('Library Library') > 0:
                publisher = publisher[:publisher.rfind('Library')]
            #print publisher
        elif x == 16:
            rights = metaList[16]['content']
        elif x == 17:
            #language = metaList[17]['content']
            language = 'English'
        elif x == 18:
            #print 'identifier: ', metaList[18]['content']
            identifier = 'lawlib:' + str(i)
        elif x == 19:
            created_date = metaList[19]['content']
        elif x == 20:
            updated_date = metaList[20]['content']
        else:
            url = href_list[i]
        x += 1
    f.write('<record>\n')
    f.write('<header>\n')
    f.write('<identifier>')
        #id = d.entries[i].id
    id = 'Lawlibguide:' + str(i)
    f.write(html_escape(id))
    f.write('</identifier>\n')
    f.write('<datestamp>2009-09-19T06:00:13Z</datestamp>\n')
    f.write('</header>\n')
    f.write('<metadata>\n')
    f.write('<oai_dc:dc xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:doc="http://www.lyncode.com/xoai" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:dc="http://purl.org/dc/elements/1.1/" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd">\n')
    ## write title
    f.write('<dc:title>')
    f.write(html_escape(title.encode('utf-8')))
    f.write('</dc:title>\n')
    f.write('<dc:type>')
    f.write('guide')
    f.write('</dc:type>\n')
    ## write creator
    f.write('<dc:creator>')
    f.write(html_escape(creator.encode('utf-8')))
    f.write('</dc:creator>\n')
    ## write subject
    f.write('<dc:subject>')
    f.write(html_escape(subject.encode('utf-8')))
    f.write('</dc:subject>\n')   
    f.write('<dc:subject>')
    f.write('research guide')
    f.write('</dc:subject>\n') 
    ## write description
    f.write('<dc:description>')
    f.write(html_escape(description.encode('utf-8')))
    f.write('</dc:description>\n')
    ## write publisher
    f.write('<dc:publisher>')
    f.write(html_escape(publisher.encode('utf-8')))
    f.write('</dc:publisher>\n')
    ## write rights
    f.write('<dc:rights>')
    f.write(html_escape(rights.encode('utf-8')))
    f.write('</dc:rights>\n')
    ## write language
    f.write('<dc:language>')
    f.write(html_escape(language.encode('utf-8')))
    f.write('</dc:language>\n')
    ## write date
    f.write('<dc:date>')
    f.write(html_escape(updated_date.encode('utf-8')))
    f.write('</dc:date>\n')
    f.write('<dc:identifier>')
    f.write(url)
    f.write('</dc:identifier>\n')
    f.write('<dc:type>')
    f.write('guide')
    f.write('</dc:type>\n') 
    f.write('</oai_dc:dc>\n</metadata>\n</record>\n')

    i += 1
f.write('</ListRecords>\n')
f.write('</OAI-PMH>\n')
f.close()
# Out:
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library
# Boston University Law Library

# %%
import urllib2
from pymarc import Field, Record
from BeautifulSoup import BeautifulSoup
import cgi
# setup a variable for excaping HTML chars
html_escape_table = {
                     "&": "&amp;",
                     '"': "&quot;",
                     "'": "&apos;",
                     ">": "&gt;",
                     "<": "&lt;",
                     }
## define a function that will escape strings of text for use in xml
def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
page = urllib2.urlopen('http://lawlibraryguides.bu.edu/browse.php')
rpage = page.read()
soup =  BeautifulSoup(rpage)
a_list = soup.fetch('a', {'class' : 'pdisplay_name'})

# %%
## open the xml file and write the header
f = open('LawGuides.xml', 'wb')
f.write('<?xml version="1.0" encoding="UTF-8"?>\n')
f.write('<OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">\n')
f.write('<responseDate>2014-07-17T21:02:57Z</responseDate>\n')
f.write('    <request verb="ListRecords" metadataPrefix="oai_dc" >http://lawlibraryguides.bu.edu/</request>\n')
f.write('<ListRecords>\n')

# %%
href_list = []
for href in a_list:
    href_list.append('http://lawlibraryguides.bu.edu' + href['href'])

## write each record
i = 0

while i < len(href_list):
    page = urllib2.urlopen(href_list[i])
    rpage = page.read()
    parsed_html =  BeautifulSoup(rpage)
    metaList = parsed_html.fetch('meta')
    x = 11

    while x < 22:
        if x == 11:
            title = metaList[11]['content']
            title = title[:-1]
            title = title[:title.rfind('.')]
        elif x == 12:
            creator = metaList[12]['content']
        elif x == 13:
            subject = metaList[13]['content']
        elif x == 14:
            description = metaList[14]['content']
        elif x == 15:
            publisher =  metaList[15]['content']
        elif x == 16:
            rights = metaList[16]['content']
        elif x == 17:
            #language = metaList[17]['content']
            language = 'English'
        elif x == 18:
            #print 'identifier: ', metaList[18]['content']
            identifier = 'lawlib:' + str(i)
        elif x == 19:
            created_date = metaList[19]['content']
        elif x == 20:
            updated_date = metaList[20]['content']
        else:
            url = href_list[i]
        x += 1
    f.write('<record>\n')
    f.write('<header>\n')
    f.write('<identifier>\n')
        #id = d.entries[i].id
    id = 'Lawlibguide:' + str(i)
    f.write(html_escape(id))
    f.write('</identifier>\n')
    f.write('<datestamp>2009-09-19T06:00:13Z</datestamp>\n')
    f.write('</header>\n')
    f.write('<metadata>\n')
    f.write('<oai_dc:dc xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:doc="http://www.lyncode.com/xoai" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:dc="http://purl.org/dc/elements/1.1/" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd">\n')
    ## write title
    f.write('<dc:title>')
    f.write(html_escape(title.encode('utf-8')))
    f.write('</dc:title>\n')
    ## write creator
    f.write('<dc:creator>')
    f.write(html_escape(creator.encode('utf-8')))
    f.write('</dc:creator>\n')
    ## write subject
    f.write('<dc:subject>')
    f.write(html_escape(subject.encode('utf-8')))
    f.write('</dc:subject>\n')   
    f.write('<dc:subject>')
    f.write('research guide')
    f.write('</dc:subject>\n') 
    ## write description
    f.write('<dc:description>')
    f.write(html_escape(description.encode('utf-8')))
    f.write('</dc:description>\n')
    ## write publisher
    f.write('<dc:publisher>')
    f.write(html_escape(publisher.encode('utf-8')))
    f.write('</dc:publisher>\n')
    ## write rights
    f.write('<dc:rights>')
    f.write(html_escape(rights.encode('utf-8')))
    f.write('</dc:rights>\n')
    ## write language
    f.write('<dc:language>')
    f.write(html_escape(language.encode('utf-8')))
    f.write('</dc:language>\n')
    ## write date
    f.write('<dc:date>')
    f.write(html_escape(updated_date.encode('utf-8')))
    f.write('</dc:date>\n')
    f.write('<dc:identifier>')
    f.write(url)
    f.write('</dc:identifier>\n')
    f.write('<dc:type>')
    f.write('guide')
    f.write('</dc:type>\n') 
    f.write('</oai_dc:dc>\n</metadata>\n</record>\n')

    i += 1
f.write('</ListRecords>\n')
f.write('</OAI-PMH>\n')
f.close()

# %%
## Test code
href_list = []
for href in a_list:
    href_list.append('http://lawlibraryguides.bu.edu' + href['href'])

## write each record
i = 0

while i < len(href_list):
    page = urllib2.urlopen(href_list[i])
    rpage = page.read()
    parsed_html =  BeautifulSoup(rpage)
    metaList = parsed_html.fetch('meta')
    x = 11
    print ' '
    while x < 22:
        if x == 11:
            title = metaList[11]['content']
            title = title[:-1]
            title = title[:title.rfind('.')]
            print 'title: ', title
            #print metaList[x]
        elif x == 12:
            print 'creator: ', metaList[12]['content']
            #print metaList[x]
        elif x == 13:
            print 'subject: ', metaList[13]['content']
            #print metaList[x]
        elif x == 14:
            print 'description: ', metaList[14]['content']
            #print metaList[x]
        elif x == 15:
            print 'publisher: ', metaList[15]['content']
            #print metaList[x]
        elif x == 16:
            print 'rights: ', metaList[16]['content']
            #print metaList[x]
        elif x == 17:
            print 'language: ', metaList[17]['content']
            #print metaList[x]
        elif x == 18:
            #print 'identifier: ', metaList[18]['content']
            print 'identifier: ', 'lawlib:' + str(i)
            #print metaList[x]
        elif x == 19:
            print 'created: ', metaList[19]['content']
            #print metaList[x]
        elif x == 20:
            print 'updated: ', metaList[20]['content']
            #print metaList[x]
        else:
            print 'url: ', href_list[i]
        x += 1
    print ' '
    
    i += 1
# Out:
#
# title:  LibGuides. A-Z Electronic Resources List
# creator:  Stefanie Weigmann, Steven Ellis
# subject:  Home A-Z Electronic Resources List LibGuides
# description:  LibGuides. A-Z Electronic Resources List. Home.
# publisher:  Boston University Law Library Library
# rights:  Copyright Boston University Law Library 2014
# language:  en
# identifier:  lawlib

# publisher:  Boston University Law Library Library
# rights:  Copyright Boston University Law Library 2014
# language:  en
# identifier:  lawlib:83
# created:  Jun 28, 2013
# updated:  Jan 16, 2014
# url:  http://lawlibraryguides.bu.edu/tutorials
# title:  LibGuides. Using the Bluebook
# creator:  Steve Donweber
# subject:  Home Using the Bluebook LibGuides
# description:  Fundamentals of legal citation
# publisher:  Boston University Law Library Library
# rights:  Copyright Boston University Law Library 2014
# language:  en
# identifier:  lawlib:84
# created:  Jul 21, 2011
# updated:  May 15, 2014
# url:  http://lawlibraryguides.bu.edu/bluebook
# title:  LibGuides. 1L Survival Guide
# creator:  Stefanie Weigmann
# subject:  Law School 101 1L Survival Guide LibGuides
# description:  LibGuides. 1L Survival Guide. Law School 101.
# publisher:  Boston University Law Library Library
# rights:  Copyright Boston University Law Library 2014
# language:  en
# identifier:  lawlib:85
# created:  Aug 20, 2010
# updated:  May 8, 2014
# url:  http://lawlibraryguides.bu.edu/1Lguide

# %%
href_list = []
for href in a_list:
    href_list.append('http://lawlibraryguides.bu.edu' + href['href'])

## write each record
i = 0
while i < len(href_list):
    page = urllib2.urlopen(href_list[i])
    rpage = page.read()
    parsed_html =  BeautifulSoup(rpage)
    metaList = parsed_html.fetch('meta')
    for i in metaList:
        f.write('<record>\n')
        f.write('<header>\n')
        f.write('<identifier>\n')
        id = 'Lawlibguide:' + str(i)
        f.write(html_escape(id))
        f.write('</identifier>\n')
        f.write('<datestamp>2009-09-19T06:00:13Z</datestamp>\n')
        f.write('</header>\n')
        f.write('<metadata>\n')
        f.write('<oai_dc:dc xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:doc="http://www.lyncode.com/xoai" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:dc="http://purl.org/dc/elements/1.1/" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd">\n')
        if d.entries[i].has_key('title'):
            title = d.entries[i].title
            f.write('<dc:title>')
            f.write(html_escape(title.encode('utf-8')))
            f.write('</dc:title>\n')
        else:
            # each record in Primo has to have a title, so we provide a default title
            title = 'untitled'
            f.write('<dc:title>')
            f.write(html_escape(title.encode('utf-8')))
            f.write('</dc:title>\n')
# Out:
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. A-Z Electronic Resources List. Home." />
# <meta name="keywords" content="Home A-Z Electronic Resources List LibGuides" />
# <meta name="author" content="Stefanie Weigmann, Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="A-Z Electronic Resources List" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. A-Z Electronic Resources List. Home." />
# <meta name="DC.Creator" content="Stefanie Weigmann, Steven Ellis" />
# <meta name="DC.Subject" content="Home A-Z Electronic Resources List LibGuides" />
# <meta name="DC.Description" content="LibGuides. A-Z Electronic Resources List. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=118797&amp;sid=1023838" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Sep 20, 2010" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Jul 11, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Advanced Bluebook Guide. The Bluebook." />
# <meta name="keywords" content="The Bluebook Advanced Bluebook Guide LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Advanced Bluebook Guide" />
# <meta name="lg_page_name" content="The Bluebook" />
# <meta name="DC.Title" content="LibGuides. Advanced Bluebook Guide. The Bluebook." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="The Bluebook Advanced Bluebook Guide LibGuides" />
# <meta name="DC.Description" content="LibGuides. Advanced Bluebook Guide. The Bluebook." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/bluebookadvanced" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 24, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 15, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Afghanistan. Home." />
# <meta name="keywords" content="Home Afghanistan LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Afghanistan" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Afghanistan. Home." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Home Afghanistan LibGuides" />
# <meta name="DC.Description" content="LibGuides. Afghanistan. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=477514&amp;sid=3911103" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jul 30, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 6, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Welcome from the Pappas Law Library!" />
# <meta name="keywords" content="Welcome! AmLaw &amp; LLM Survival Guide LibGuides" />
# <meta name="author" content="David Bachman" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="AmLaw &amp; LLM Survival Guide" />
# <meta name="lg_page_name" content="Welcome!" />
# <meta name="DC.Title" content="LibGuides. AmLaw &amp; LLM Survival Guide. Welcome!." />
# <meta name="DC.Creator" content="David Bachman" />
# <meta name="DC.Subject" content="Welcome! AmLaw &amp; LLM Survival Guide LibGuides" />
# <meta name="DC.Description" content="Welcome from the Pappas Law Library!" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=142705&amp;sid=2013311" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 30, 2010" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 9, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Antitrust and Trade. Home." />
# <meta name="keywords" content="Home Antitrust and Trade LibGuides" />
# <meta name="author" content="Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Antitrust and Trade" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Antitrust and Trade. Home." />
# <meta name="DC.Creator" content="Steven Ellis" />
# <meta name="DC.Subject" content="Home Antitrust and Trade LibGuides" />
# <meta name="DC.Description" content="LibGuides. Antitrust and Trade. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=467495&amp;sid=3827460" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 24, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 29, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Apps for Law Students and Lawyers. Guide Overview." />
# <meta name="keywords" content="Guide Overview Apps for Law Students and Lawyers LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Apps for Law Students and Lawyers" />
# <meta name="lg_page_name" content="Guide Overview" />
# <meta name="DC.Title" content="LibGuides. Apps for Law Students and Lawyers. Guide Overview." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Guide Overview Apps for Law Students and Lawyers LibGuides" />
# <meta name="DC.Description" content="LibGuides. Apps for Law Students and Lawyers. Guide Overview." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=315983&amp;sid=2585623" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Mar 9, 2012" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Mar 24, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Art, Entertainment, and Sports Law. Quick Links." />
# <meta name="keywords" content="Quick Links Art, Entertainment, and Sports Law LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Art, Entertainment, and Sports Law" />
# <meta name="lg_page_name" content="Quick Links" />
# <meta name="DC.Title" content="LibGuides. Art, Entertainment, and Sports Law. Quick Links." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Quick Links Art, Entertainment, and Sports Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Art, Entertainment, and Sports Law. Quick Links." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=489727&amp;sid=4016925" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jul 25, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 12, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Austria. Home." />
# <meta name="keywords" content="Home Austria LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Austria" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Austria. Home." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Home Austria LibGuides" />
# <meta name="DC.Description" content="LibGuides. Austria. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=491228&amp;sid=4032181" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jul 30, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 6, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Banking and Financial Law. Quick Start." />
# <meta name="keywords" content="Quick Start Banking and Financial Law LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Banking and Financial Law" />
# <meta name="lg_page_name" content="Quick Start" />
# <meta name="DC.Title" content="LibGuides. Banking and Financial Law. Quick Start." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Quick Start Banking and Financial Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Banking and Financial Law. Quick Start." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=468555&amp;sid=3835745" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 23, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 12, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Welcome from the Pappas Law Library!" />
# <meta name="keywords" content="Welcome! Banking LLM Survival Guide LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Banking LLM Survival Guide" />
# <meta name="lg_page_name" content="Welcome!" />
# <meta name="DC.Title" content="LibGuides. Banking LLM Survival Guide. Welcome!." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Welcome! Banking LLM Survival Guide LibGuides" />
# <meta name="DC.Description" content="Welcome from the Pappas Law Library!" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=370344&amp;sid=3033698" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 28, 2012" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 12, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Belgium. Home." />
# <meta name="keywords" content="Home Belgium LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Belgium" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Belgium. Home." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Home Belgium LibGuides" />
# <meta name="DC.Description" content="LibGuides. Belgium. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=491378&amp;sid=4033479" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jul 30, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 6, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. BNA Premier. BNA by Title." />
# <meta name="keywords" content="BNA by Title BNA Premier LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="BNA Premier" />
# <meta name="lg_page_name" content="BNA by Title" />
# <meta name="DC.Title" content="LibGuides. BNA Premier. BNA by Title." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="BNA by Title BNA Premier LibGuides" />
# <meta name="DC.Description" content="LibGuides. BNA Premier. BNA by Title." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=150433&amp;sid=1277367" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Sep 21, 2010" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 28, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Business and Economics Resources. Home." />
# <meta name="keywords" content="Home Business and Economics Resources LibGuides" />
# <meta name="author" content="Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Business and Economics Resources" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Business and Economics Resources. Home." />
# <meta name="DC.Creator" content="Steven Ellis" />
# <meta name="DC.Subject" content="Home Business and Economics Resources LibGuides" />
# <meta name="DC.Description" content="LibGuides. Business and Economics Resources. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=467536&amp;sid=3827759" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 29, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 5, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Career Resources at the Library. Using General Career Resources." />
# <meta name="keywords" content="Using General Career Resources Career Resources at the Library LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Career Resources at the Library" />
# <meta name="lg_page_name" content="Using General Career Resources" />
# <meta name="DC.Title" content="LibGuides. Career Resources at the Library. Using General Career Resources." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Using General Career Resources Career Resources at the Library LibGuides" />
# <meta name="DC.Description" content="LibGuides. Career Resources at the Library. Using General Career Resources." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=325174&amp;sid=2661094" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 29, 2012" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 13, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="This guide brings together tools and tricks to help law students organize research and make Bluebooked citations." />
# <meta name="keywords" content="Home Citation &amp; Organization Tools LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Citation &amp; Organization Tools" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Citation &amp; Organization Tools. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home Citation &amp; Organization Tools LibGuides" />
# <meta name="DC.Description" content="This guide brings together tools and tricks to help law students organize research and make Bluebooked citations." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=210292&amp;sid=1750902" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 9, 2011" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 13, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Clerkship Resources. Home." />
# <meta name="keywords" content="Home Clerkship Resources LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Clerkship Resources" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Clerkship Resources. Home." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Home Clerkship Resources LibGuides" />
# <meta name="DC.Description" content="LibGuides. Clerkship Resources. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=326246&amp;sid=2669638" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Apr 17, 2012" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 28, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Clinical Programs Research Guide and Portal. Quick Start." />
# <meta name="keywords" content="Quick Start Clinical Programs Research Guide and Portal LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Clinical Programs Research Guide and Portal" />
# <meta name="lg_page_name" content="Quick Start" />
# <meta name="DC.Title" content="LibGuides. Clinical Programs Research Guide and Portal. Quick Start." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Quick Start Clinical Programs Research Guide and Portal LibGuides" />
# <meta name="DC.Description" content="LibGuides. Clinical Programs Research Guide and Portal. Quick Start." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=133963&amp;sid=1149126" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 4, 2010" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 13, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Commercial law. Home." />
# <meta name="keywords" content="Home Commercial law LibGuides" />
# <meta name="author" content="Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Commercial law" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Commercial law. Home." />
# <meta name="DC.Creator" content="Steven Ellis" />
# <meta name="DC.Subject" content="Home Commercial law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Commercial law. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=467521&amp;sid=3827621" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 29, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 29, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Computer Law, Cyberlaw &amp; E-Commerce. Useful Resources." />
# <meta name="keywords" content="Useful Resources Computer Law, Cyberlaw &amp; E-Commerce LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Computer Law, Cyberlaw &amp; E-Commerce" />
# <meta name="lg_page_name" content="Useful Resources" />
# <meta name="DC.Title" content="LibGuides. Computer Law, Cyberlaw &amp; E-Commerce. Useful Resources." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Useful Resources Computer Law, Cyberlaw &amp; E-Commerce LibGuides" />
# <meta name="DC.Description" content="LibGuides. Computer Law, Cyberlaw &amp; E-Commerce. Useful Resources." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/complaw" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 29, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 6, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Introduction to Patent Law Research" />
# <meta name="keywords" content="Intro Copyright Law Research Guide LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Copyright Law Research Guide" />
# <meta name="lg_page_name" content="Intro" />
# <meta name="DC.Title" content="LibGuides. Copyright Law Research Guide. Intro." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Intro Copyright Law Research Guide LibGuides" />
# <meta name="DC.Description" content="Introduction to Patent Law Research" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=203372&amp;sid=1698913" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Apr 13, 2011" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 8, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Criminal Law. Home." />
# <meta name="keywords" content="Home Criminal Law LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Criminal Law" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Criminal Law. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home Criminal Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Criminal Law. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=455438&amp;sid=3730907" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 30, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 7, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Education Law. Home." />
# <meta name="keywords" content="Home Education Law LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Education Law" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Education Law. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home Education Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Education Law. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=477882&amp;sid=3914162" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jun 19, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 7, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Employment and Labor Law. Home." />
# <meta name="keywords" content="Home Employment and Labor Law LibGuides" />
# <meta name="author" content="Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Employment and Labor Law" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Employment and Labor Law. Home." />
# <meta name="DC.Creator" content="Steven Ellis" />
# <meta name="DC.Subject" content="Home Employment and Labor Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Employment and Labor Law. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=467545&amp;sid=3827830" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 29, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Aug 6, 2013" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Environmental Law. Home." />
# <meta name="keywords" content="Home Environmental Law LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Environmental Law" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Environmental Law. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home Environmental Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Environmental Law. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=455491&amp;sid=3731336" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Apr 13, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Oct 23, 2013" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Non-JD research guide" />
# <meta name="keywords" content="Home Environmental Law Research Class LibGuides" />
# <meta name="author" content="Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Environmental Law Research Class" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Environmental Law Research Class. Home." />
# <meta name="DC.Creator" content="Steven Ellis" />
# <meta name="DC.Subject" content="Home Environmental Law Research Class LibGuides" />
# <meta name="DC.Description" content="Non-JD research guide" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=512930&amp;sid=4220587" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Sep 18, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Sep 18, 2013" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. eResources by Subject. Home." />
# <meta name="keywords" content="Home eResources by Subject LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="eResources by Subject" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. eResources by Subject. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home eResources by Subject LibGuides" />
# <meta name="DC.Description" content="LibGuides. eResources by Subject. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=495111&amp;sid=4067783" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 8, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Apr 14, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Ethics &amp; Professional Responsibility. Home." />
# <meta name="keywords" content="Home Ethics &amp; Professional Responsibility LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Ethics &amp; Professional Responsibility" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Ethics &amp; Professional Responsibility. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home Ethics &amp; Professional Responsibility LibGuides" />
# <meta name="DC.Description" content="LibGuides. Ethics &amp; Professional Responsibility. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/legalethics" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="May 29, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Apr 28, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. EU Law Research. Home." />
# <meta name="keywords" content="Home EU Law Research LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="EU Law Research" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. EU Law Research. Home." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Home EU Law Research LibGuides" />
# <meta name="DC.Description" content="LibGuides. EU Law Research. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=445123&amp;sid=3646226" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jun 17, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 7, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. European Union Human Rights. Conventions, Treaties, &amp; Secondary Legislation." />
# <meta name="keywords" content="Conventions, Treaties, &amp; Secondary Legislation European Union Human Rights LibGuides" />
# <meta name="author" content="Ellen Richardson, David Bachman" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="European Union Human Rights" />
# <meta name="lg_page_name" content="Conventions, Treaties, &amp; Secondary Legislation" />
# <meta name="DC.Title" content="LibGuides. European Union Human Rights. Conventions, Treaties, &amp; Secondary Legislation." />
# <meta name="DC.Creator" content="Ellen Richardson, David Bachman" />
# <meta name="DC.Subject" content="Conventions, Treaties, &amp; Secondary Legislation European Union Human Rights LibGuides" />
# <meta name="DC.Description" content="LibGuides. European Union Human Rights. Conventions, Treaties, &amp; Secondary Legislation." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=479109&amp;sid=3925065" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jun 24, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Jan 8, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Evidence. Quick Links." />
# <meta name="keywords" content="Quick Links Evidence LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Evidence" />
# <meta name="lg_page_name" content="Quick Links" />
# <meta name="DC.Title" content="LibGuides. Evidence. Quick Links." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Quick Links Evidence LibGuides" />
# <meta name="DC.Description" content="LibGuides. Evidence. Quick Links." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=489724&amp;sid=4016900" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jul 25, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 12, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Exam Preparation. Introduction." />
# <meta name="keywords" content="Introduction Exam Preparation LibGuides" />
# <meta name="author" content="Steven Ellis" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# ...
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Torts Research Tools. Home." />
# <meta name="keywords" content="Home Torts Research Tools LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Torts Research Tools" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Torts Research Tools. Home." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Home Torts Research Tools LibGuides" />
# <meta name="DC.Description" content="LibGuides. Torts Research Tools. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=135129&amp;sid=1157994" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 9, 2010" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 15, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Introduction to Patent Law Research" />
# <meta name="keywords" content="Introduction Trade Secret Law Research Guide LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Trade Secret Law Research Guide" />
# <meta name="lg_page_name" content="Introduction" />
# <meta name="DC.Title" content="LibGuides. Trade Secret Law Research Guide. Introduction." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Introduction Trade Secret Law Research Guide LibGuides" />
# <meta name="DC.Description" content="Introduction to Patent Law Research" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=208224&amp;sid=1735591" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Apr 29, 2011" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 9, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Introduction to Patent Law Research" />
# <meta name="keywords" content="Introduction Trademark Law Research Guide LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Trademark Law Research Guide" />
# <meta name="lg_page_name" content="Introduction" />
# <meta name="DC.Title" content="LibGuides. Trademark Law Research Guide. Introduction." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Introduction Trademark Law Research Guide LibGuides" />
# <meta name="DC.Description" content="Introduction to Patent Law Research" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=192243&amp;sid=1611765" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Mar 2, 2011" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 9, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Transfer Survival Guide. Welcome to BU Law." />
# <meta name="keywords" content="Welcome to BU Law Transfer Survival Guide LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Transfer Survival Guide" />
# <meta name="lg_page_name" content="Welcome to BU Law" />
# <meta name="DC.Title" content="LibGuides. Transfer Survival Guide. Welcome to BU Law." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Welcome to BU Law Transfer Survival Guide LibGuides" />
# <meta name="DC.Description" content="LibGuides. Transfer Survival Guide. Welcome to BU Law." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=372214&amp;sid=3048966" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 30, 2012" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 8, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Transnational Criminal Law. Home." />
# <meta name="keywords" content="Home Transnational Criminal Law LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Transnational Criminal Law" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Transnational Criminal Law. Home." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Home Transnational Criminal Law LibGuides" />
# <meta name="DC.Description" content="LibGuides. Transnational Criminal Law. Home." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=479384&amp;sid=3927300" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jun 24, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Apr 28, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Resources for finding treaties and other international agreements, and related materials. Tips on research tasks most frequently performed by users" />
# <meta name="keywords" content="Intro Treaty Research LibGuides" />
# <meta name="author" content="David Bachman" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Treaty Research" />
# <meta name="lg_page_name" content="Intro" />
# <meta name="DC.Title" content="LibGuides. Treaty Research. Intro." />
# <meta name="DC.Creator" content="David Bachman" />
# <meta name="DC.Subject" content="Intro Treaty Research LibGuides" />
# <meta name="DC.Description" content="Resources for finding treaties and other international agreements, and related materials. Tips on research tasks most frequently performed by users" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=200490&amp;sid=3784441" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 9, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Mar 28, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="This guide is related to the Treaty Research Guide. It provides links to treaty resources arranged by topic." />
# <meta name="keywords" content="Home Treaty Research - By Topic LibGuides" />
# <meta name="author" content="David Bachman" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Treaty Research - By Topic" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Treaty Research - By Topic. Home." />
# <meta name="DC.Creator" content="David Bachman" />
# <meta name="DC.Subject" content="Home Treaty Research - By Topic LibGuides" />
# <meta name="DC.Description" content="This guide is related to the Treaty Research Guide. It provides links to treaty resources arranged by topic." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=465121&amp;sid=3808791" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 9, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Jan 26, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. Tutorials. Basic Research Tutorials." />
# <meta name="keywords" content="Basic Research Tutorials Tutorials LibGuides" />
# <meta name="author" content="Ellen Richardson" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Tutorials" />
# <meta name="lg_page_name" content="Basic Research Tutorials" />
# <meta name="DC.Title" content="LibGuides. Tutorials. Basic Research Tutorials." />
# <meta name="DC.Creator" content="Ellen Richardson" />
# <meta name="DC.Subject" content="Basic Research Tutorials Tutorials LibGuides" />
# <meta name="DC.Description" content="LibGuides. Tutorials. Basic Research Tutorials." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=473880&amp;sid=3880514" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jun 28, 2013" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="Jan 16, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="Fundamentals of legal citation" />
# <meta name="keywords" content="Home Using the Bluebook LibGuides" />
# <meta name="author" content="Steve Donweber" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="Using the Bluebook" />
# <meta name="lg_page_name" content="Home" />
# <meta name="DC.Title" content="LibGuides. Using the Bluebook. Home." />
# <meta name="DC.Creator" content="Steve Donweber" />
# <meta name="DC.Subject" content="Home Using the Bluebook LibGuides" />
# <meta name="DC.Description" content="Fundamentals of legal citation" />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=221166&amp;sid=1836039" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Jul 21, 2011" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 15, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noarchive" />
# <meta name="description" content="LibGuides. 1L Survival Guide. Law School 101." />
# <meta name="keywords" content="Law School 101 1L Survival Guide LibGuides" />
# <meta name="author" content="Stefanie Weigmann" />
# <meta name="copyright" content="Copyright Boston University Law Library 2014" />
# <meta name="lg_institution_name" content="Boston University Law Library" />
# <meta name="lg_system_name" content="LibGuides" />
# <meta name="lg_guide_name" content="1L Survival Guide" />
# <meta name="lg_page_name" content="Law School 101" />
# <meta name="DC.Title" content="LibGuides. 1L Survival Guide. Law School 101." />
# <meta name="DC.Creator" content="Stefanie Weigmann" />
# <meta name="DC.Subject" content="Law School 101 1L Survival Guide LibGuides" />
# <meta name="DC.Description" content="LibGuides. 1L Survival Guide. Law School 101." />
# <meta name="DC.Publisher" content="Boston University Law Library Library" />
# <meta name="DC.Rights" content="Copyright Boston University Law Library 2014" />
# <meta name="DC.Language" content="en" />
# <meta name="DC.Identifier" scheme="URI" content="http://lawlibraryguides.bu.edu/content.php?pid=123207&amp;sid=1058872" />
# <meta name="DC.Date.Created" scheme="ISO8601" content="Aug 20, 2010" />
# <meta name="DC.Date.Modified" scheme="ISO8601" content="May 8, 2014" />
# <meta name="DC.Unused" content="Contributor, Date, Type, Format, Source, Relation, Coverage" />
#
# ++++++++
